# %%
import pandas as pd
import numpy as np

# Setări utile pentru display
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: f'{x:,.2f}')

# Citește datele
df = pd.read_parquet('data/vanzari_ro.parquet')

print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (50000, 9)
#    order_id  customer_id          order_date       oras  categorie    canal  \
# 0         1          861 2024-04-28 03:00:00  Timișoara  Cosmetice   Online
# 1         2         3773 2024-11-25 20:00:00       Iași  Cosmetice      App
# 2         3         3093 2024-08-02 17:00:00  București       Casă  Magazin
# 3         4          467 2024-11-17 04:00:00  București   Alimente      App
# 4         5         4427 2024-05-28 06:00:00  București   Alimente   Online
#
#    amount_ron  discount_pct  rating
# 0       62.43            15    4.00
# 1       76.51             0    5.00
# 2       44.08            20    5.00
# 3       85.68             0     NaN
# 4       44.08             0    4.00
